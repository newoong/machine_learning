# %%
## Necessary packages
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import pandas as pd
import import_ipynb
import warnings
warnings.filterwarnings("ignore")

# 1. TimeGAN model
from timegan import timegan
# 2. Data loading
from data_loading import real_data_loading
# 3. Metrics
from metrics.discriminative_metrics import discriminative_score_metrics
from metrics.predictive_metrics import predictive_score_metrics
from metrics.visualization_metrics import visualization

# %%
## Data loading
data_name = 'onephase'
seq_len = 24

if data_name in ['onephase', 'phase2phase']:
  ori_data = pd.read_excel(f'../ElecCarFault/{data_name}.xlsx',engine='openpyxl')
  ori_data.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
  ori_data.columns=['Time','Va','Vb','Vc','rpm','RPM_Ref','Ide','Idref','Iqe','Iqref','Ia','Ib','Ic']
    
print(data_name + ' dataset is ready.')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique in database. History logging moved to new session 206
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-445c46b7be8c>", line 6, in <module>
#     ori_data = pd.read_excel(f'../ElecCarFault/{data_name}.xlsx',engine='openpyxl')
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\util\_decorators.py", line 296, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_base.py", line 304, in read_excel
#     io = ExcelFile(io, engine=engine)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_base.py", line 867, in __init__
#     self._reader = self._engines[engine](self._io)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_openpyxl.py", line 479, in __init__
#     import_optional_dependency("openpyxl")
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\compat\_optional.py", line 110, in import_optional_dependency
#     raise ImportError(msg) from None
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ImportError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 953, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-445c46b7be8c>", line 6, in <module>
#     ori_data = pd.read_excel(f'../ElecCarFault/{data_name}.xlsx',engine='openpyxl')
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\util\_decorators.py", line 296, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_base.py", line 304, in read_excel
#     io = ExcelFile(io, engine=engine)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_base.py", line 867, in __init__
#     self._reader = self._engines[engine](self._io)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_openpyxl.py", line 479, in __init__
#     import_optional_dependency("openpyxl")
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\compat\_optional.py", line 110, in import_optional_dependency
#     raise ImportError(msg) from None
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ImportError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 953, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-445c46b7be8c>", line 6, in <module>
#     ori_data = pd.read_excel(f'../ElecCarFault/{data_name}.xlsx',engine='openpyxl')
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\util\_decorators.py", line 296, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_base.py", line 304, in read_excel
#     io = ExcelFile(io, engine=engine)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_base.py", line 867, in __init__
#     self._reader = self._engines[engine](self._io)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_openpyxl.py", line 479, in __init__
#     import_optional_dependency("openpyxl")
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\compat\_optional.py", line 110, in import_optional_dependency
#     raise ImportError(msg) from None
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ImportError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1211, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 953, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'

# %%
ori_data = pd.read_excel('../ElecCarFault/onephase.xlsx')#,engine='openpyxl') #np.loadtxt('data/stock_data.csv', delimiter = ",",skiprows = 1)
#ori_data.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
#ori_data.columns=['Time','Va','Vb','Vc','rpm','RPM_Ref','Ide','Idref','Iqe','Iqref','Ia','Ib','Ic']
ori_data
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique in database. History logging moved to new session 208
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-c350af3b6cf0>", line 1, in <module>
#     ori_data = pd.read_excel('../ElecCarFault/onephase.xlsx')#,engine='openpyxl') #np.loadtxt('data/stock_data.csv', delimiter = ",",skiprows = 1)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\util\_decorators.py", line 296, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_base.py", line 304, in read_excel
#     io = ExcelFile(io, engine=engine)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_base.py", line 867, in __init__
#     self._reader = self._engines[engine](self._io)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_xlrd.py", line 21, in __init__
#     import_optional_dependency("xlrd", extra=err_msg)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\compat\_optional.py", line 110, in import_optional_dependency
#     raise ImportError(msg) from None
# ImportError: Missing optional dependency 'xlrd'. Install xlrd >= 1.0.0 for Excel support Use pip or conda to install xlrd.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ImportError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 953, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-c350af3b6cf0>", line 1, in <module>
#     ori_data = pd.read_excel('../ElecCarFault/onephase.xlsx')#,engine='openpyxl') #np.loadtxt('data/stock_data.csv', delimiter = ",",skiprows = 1)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\util\_decorators.py", line 296, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_base.py", line 304, in read_excel
#     io = ExcelFile(io, engine=engine)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_base.py", line 867, in __init__
#     self._reader = self._engines[engine](self._io)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_xlrd.py", line 21, in __init__
#     import_optional_dependency("xlrd", extra=err_msg)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\compat\_optional.py", line 110, in import_optional_dependency
#     raise ImportError(msg) from None
# ImportError: Missing optional dependency 'xlrd'. Install xlrd >= 1.0.0 for Excel support Use pip or conda to install xlrd.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ImportError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 953, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-c350af3b6cf0>", line 1, in <module>
#     ori_data = pd.read_excel('../ElecCarFault/onephase.xlsx')#,engine='openpyxl') #np.loadtxt('data/stock_data.csv', delimiter = ",",skiprows = 1)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\util\_decorators.py", line 296, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_base.py", line 304, in read_excel
#     io = ExcelFile(io, engine=engine)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_base.py", line 867, in __init__
#     self._reader = self._engines[engine](self._io)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\io\excel\_xlrd.py", line 21, in __init__
#     import_optional_dependency("xlrd", extra=err_msg)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\pandas\compat\_optional.py", line 110, in import_optional_dependency
#     raise ImportError(msg) from None
# ImportError: Missing optional dependency 'xlrd'. Install xlrd >= 1.0.0 for Excel support Use pip or conda to install xlrd.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ImportError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1211, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\sewoong\anaconda3\envs\env_tf\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 953, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
